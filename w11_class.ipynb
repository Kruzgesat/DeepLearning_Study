# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *

(X_train, y_train), (X_test, y_test) = keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 17s 0us/step

# %%
plt.figure()
plt.imshow(X_train[1])
plt.colorbar()

X_test = X_test / 255.0
X_train = X_train / 255.0

# %%
model = Sequential()

model.add(Conv2D(64, activation='relu', kernel_size= (3,3)))
model.add(MaxPooling2D(pool_size= (2,2)))
model.add(Conv2D(64, activation='relu', kernel_size= (3,3)))
model.add(Flatten(input_shape=(32,32,3)))
model.add(Dense(80, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=10, verbose= 1, validation_split=0.3)
# Out:
# Epoch 1/10
# 1094/1094 [==============================] - 14s 13ms/step - loss: 0.3134 - accuracy: 0.8898 - val_loss: 0.3470 - val_accuracy: 0.8759
# Epoch 2/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.2461 - accuracy: 0.9143 - val_loss: 0.3889 - val_accuracy: 0.8627
# Epoch 3/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.1928 - accuracy: 0.9340 - val_loss: 0.4516 - val_accuracy: 0.8469
# Epoch 4/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.1600 - accuracy: 0.9447 - val_loss: 0.5539 - val_accuracy: 0.8321
# Epoch 5/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.1468 - accuracy: 0.9499 - val_loss: 0.6956 - val_accuracy: 0.8061
# Epoch 6/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.1169 - accuracy: 0.9589 - val_loss: 0.6993 - val_accuracy: 0.8052
# Epoch 7/10
# 1094/1094 [==============================] - 13s 11ms/step - loss: 0.1121 - accuracy: 0.9618 - val_loss: 0.7880 - val_accuracy: 0.7958
# Epoch 8/10
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0948 - accuracy: 0.9670 - val_loss: 0.8716 - val_accuracy: 0.7894
# Epoch 9/10
# 1094/1094 [==============================] - 12s 11ms/step - loss: 0.0895 - accuracy: 0.9701 - val_loss: 0.9382 - val_accuracy: 0.7834
# Epoch 10/10
# 1094/1094 [==============================] - 13s 12ms/step - loss: 0.0799 - accuracy: 0.9726 - val_loss: 1.0499 - val_accuracy: 0.7793

# %%
plt.figure()
plt.imshow(X_train[0])

# %%
y_pred = model.predict(X_test)
print('Answer : ', y_test[0])
print('Prediction : ', y_pred[0])
# Out:
# 313/313 [==============================] - 1s 3ms/step
# Answer :  [3]
# Prediction :  [7.1890718e-12 4.6923461e-22 2.2223094e-12 9.9999964e-01 1.0092186e-18
#  4.9385172e-14 3.1017382e-07 3.5099603e-20 8.5995957e-09 3.5670658e-15]
